# %% [markdown]
# ## Preparing environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
#     libedit-3.1.20191231       |       h14c3975_1         121 KB
#     pyopenssl-20.0.0           |     pyhd3eb1b0_1          48 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     conda-package-handling-1.7.2|   py36h03888b9_0         967 KB
#     conda-4.9.2                |   py36h06a4308_0         3.1 MB
#     tqdm-4.54.1                |     pyhd3eb1b0_0          54 KB
#     urllib3-1.25.11            |             py_0          93 KB
# ...

# %%
# !conda env create -f '/content/drive/My Drive/thesisdata/envir.yml'
# Out:
# done
# done
#
# ...
# giflib-5.2.1         | 80 KB     | : 100% 1.0/1 [00:00<00:00, 11.06it/s]
# pandocfilters-1.4.2  | 13 KB     | : 100% 1.0/1 [00:00<00:00, 28.09it/s]
# astor-0.8.0          | 45 KB     | : 100% 1.0/1 [00:00<00:00, 27.11it/s]
# zeromq-4.3.2         | 675 KB    | : 100% 1.0/1 [00:00<00:00,  2.33it/s]
# ujson-3.2.0          | 48 KB     | : 100% 1.0/1 [00:00<00:00,  8.01it/s]
# pylint-2.3.1         | 829 KB    | : 100% 1.0/1 [00:00<00:00,  2.09it/s]
# ipython_genutils-0.2 | 39 KB     | : 100% 1.0/1 [00:00<00:00, 25.88it/s]
# pluggy-0.13.1        | 32 KB     | : 100% 1.0/1 [00:00<00:00, 26.18it/s]
# bleach-3.2.1         | 111 KB    | : 100% 1.0/1 [00:00<00:00, 20.81it/s]
# liblapacke-3.8.0     | 11 KB     | : 100% 1.0/1 [00:00<00:00, 32.80it/s]
# python-language-serv | 47 KB     | : 100% 1.0/1 [00:00<00:00,  6.87it/s]
# seaborn-0.11.0       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  9.36it/s]
# pyqt-5.9.2           | 5.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
# ...

# %% [markdown]
# ## Getting Data from google drive

# %%
## copy zip from colab for speedup
#!cp '/content/drive/My Drive/thesisdata/Thesis 11 dec.zip' 'thesisdata.zip'
#!unzip 'thesisdata.zip' 
## Now change the working directory

# %%
cp -rv '/content/drive/MyDrive/thesisdata/tempModels/11_dec_full_proj' 'Thesis'

# %% [markdown]
# ## Training Time

# %%
# %cd '/content/Thesis/SCAN-algorithm'a
# Out:
# /content/Thesis/SCAN-algorithm

# %% [markdown]
# ## pretext stage

# %%
#pretext stage

# !source activate gpu && python simclr.py --config_env configs/env.yml --config_exp configs/pretext/simclr_batsnet.yml
# Out:
# {'setup': 'simclr', 'backbone': 'resnet18', 'model_kwargs': {'head': 'mlp', 'features_dim': 128}, 'train_db_name': 'batsnet', 'val_db_name': 'batsnet', 'num_classes': 5, 'criterion': 'simclr', 'criterion_kwargs': {'temperature': 0.1}, 'epochs': 15, 'optimizer': 'sgd', 'optimizer_kwargs': {'nesterov': False, 'weight_decay': 0.0001, 'momentum': 0.9, 'lr': 0.4}, 'scheduler': 'cosine', 'scheduler_kwargs': {'lr_decay_rate': 0.1}, 'batch_size': 5, 'num_workers': 8, 'augmentation_strategy': 'batsnet_strategy', 'augmentation_kwargs': {'crop_size': 360, 'color_jitter_random_apply': {'p': 0.8}, 'color_jitter': {'brightness': 0.4, 'contrast': 0.4, 'saturation': 0.4, 'hue': 0.1}, 'random_grayscale': {'p': 0.2}, 'normalize': {'mean': [0.4914, 0.4822, 0.4465], 'std': [0.2023, 0.1994, 0.201]}}, 'transformation_kwargs': {'crop_size': 360, 'normalize': {'mean': [0.4914, 0.4822, 0.4465], 'std': [0.2023, 0.1994, 0.201]}}, 'pretext_dir': '/content/Thesis/SCAN-algorithm/repository_eccv/batsnet/pretext', 
# ...

# %% [markdown]
# ### SCAN stage

# %%
# !source activate gpu && python scan.py --config_env configs/env.yml --config_exp configs/scan/scan_batsnet.yml
# Out:
# {'setup': 'scan', 'criterion': 'scan', 'criterion_kwargs': {'entropy_weight': 5.0}, 'update_cluster_head_only': False, 'num_heads': 1, 'backbone': 'resnet18', 'train_db_name': 'batsnet', 'val_db_name': 'batsnet', 'num_classes': 5, 'num_neighbors': 20, 'augmentation_strategy': 'batsnet_strategy', 'augmentation_kwargs': {'crop_size': 360, 'normalize': {'mean': [0.4914, 0.4822, 0.4465], 'std': [0.2023, 0.1994, 0.201]}, 'num_strong_augs': 4, 'cutout_kwargs': {'n_holes': 1, 'length': 16, 'random': True}}, 'transformation_kwargs': {'crop_size': 360, 'normalize': {'mean': [0.4914, 0.4822, 0.4465], 'std': [0.2023, 0.1994, 0.201]}}, 'optimizer': 'adam', 'optimizer_kwargs': {'lr': 0.0001, 'weight_decay': 0.0001}, 'epochs': 15, 'batch_size': 5, 'num_workers': 8, 'scheduler': 'constant', 'pretext_dir': '/content/Thesis/SCAN-algorithm/repository_eccv/batsnet/pretext', 'pretext_checkpoint': '/content/Thesis/SCAN-algorithm/repository_eccv/batsnet/pretext/checkpoint.pth.tar', 'pretext_model': '/cont
# ...

# %% [markdown]
# ### Self-Label Stage

# %%
# !source activate gpu && python selflabel.py --config_env configs/env.yml --config_exp configs/selflabel/selflabel_batsnet.yml
# Out:
# {'setup': 'selflabel', 'confidence_threshold': 0.2, 'use_ema': True, 'ema_alpha': 0.999, 'criterion': 'confidence-cross-entropy', 'criterion_kwargs': {'apply_class_balancing': False}, 'backbone': 'resnet18', 'num_heads': 1, 'train_db_name': 'batsnet', 'val_db_name': 'batsnet', 'num_classes': 5, 'augmentation_strategy': 'batsnet_strategy', 'augmentation_kwargs': {'crop_size': 360, 'normalize': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}, 'num_strong_augs': 4, 'cutout_kwargs': {'n_holes': 1, 'length': 75, 'random': True}}, 'transformation_kwargs': {'crop_size': 360, 'normalize': {'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225]}}, 'optimizer': 'sgd', 'optimizer_kwargs': {'lr': 0.03, 'weight_decay': 0.0, 'nesterov': False, 'momentum': 0.9}, 'epochs': 15, 'batch_size': 15, 'num_workers': 8, 'scheduler': 'constant', 'pretext_dir': '/content/Thesis/SCAN-algorithm/repository_eccv/batsnet/pretext', 'pretext_checkpoint': '/content/Thesis/SCAN-algorithm/repository_
# ...

# %%
#temporarily saving the models 21 

#!cp -r '/content/Thesis/SCAN-algorithm/repository_eccv/batsnet' '/content/drive/My Drive/thesisdata/tempModels'

# %%
#taking backup of all the files
# !zip -r '/content/Thesis_11dec_colab.zip' '/content/Thesis'
# Out:
#   adding: content/Thesis/ (stored 0%)
#   adding: content/Thesis/audio data analysis/ (stored 0%)
#   adding: content/Thesis/audio data analysis/log.txt (deflated 95%)
#   adding: content/Thesis/audio data analysis/all_stats (backup copy).csv (deflated 82%)
#   adding: content/Thesis/audio data analysis/all_stats.csv (deflated 82%)
#   adding: content/Thesis/audio data analysis/audio-clustering/ (stored 0%)
#   adding: content/Thesis/audio data analysis/audio-clustering/plots/ (stored 0%)
#   adding: content/Thesis/audio data analysis/audio-clustering/plots/mel spectrograms/ (stored 0%)
#   adding: content/Thesis/audio data analysis/audio-clustering/plots/signals/ (stored 0%)
#   adding: content/Thesis/audio data analysis/audio-clustering/plots/ffts/ (stored 0%)
#   adding: content/Thesis/audio data analysis/audio-clustering/plots/spectrograms/ (stored 0%)
#   adding: content/Thesis/audio data analysis/audio-clustering/plots/spectrograms/results/ (stored 0%)
# ...
